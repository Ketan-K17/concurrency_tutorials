# %% [markdown]
# ### 1. Unit Tests
#
# You use the unittest aka pyunit package for your unit tests...
# Unit tests are used to test a singular function in your codebase usually.
#
#
# Here's a barebones test-suite for a function named `simpleFunction()`

# %%
import unittest

def simpleFunction(x):
    return x + 1
class SimpleFunctionTest(unittest.TestCase):
    def setUp(self):
        print("This is run before all of our tests have a chance to execute")
        
    def tearDown(self):
        print("This is executed after all of our tests have completed")

    def test_simple_function(self):
        print("Testing that our function works with positive tests")

        self.assertEqual(simpleFunction(2), 3)
        self.assertEqual(simpleFunction(234135145145432143214321432),
234135145145432143214321433)
        self.assertEqual(simpleFunction(0), 1)


if __name__ == '__main__':
    unittest.main()

# NOTE: when you run unittest.main(), all methods in your TestCase child class starting with 'test' are collected. These methods are then individually run, sandwiched by a setUp() call prior and tearDown() call afters...

# so if you had test1(), test2(), test3(), 
# flow = setup() -> test1() -> teardown() -> setup() -> test2() -> teardown() -> setup() -> test3() -> teardown()

# %% [markdown]
# There's no clear approaches for unit-testing multi-threaded code... Some pointers -
#
# 1. separate unit-testing of your single-threaded and multi-threaded code.
# 2. for your multi-threaded sections, maybe have load-tests which can see how much traffic it can handle perhaps (I can't really appreciate what this means yet, just writing is down...)

# %% [markdown]
# ### 2. Integration Tests
#
# There was nothing taught about integration tests sadly... All i know so far is that integration tests cover entire sections / flows of your code, and a successful integration test is your indicator that that flow works well, if there's an issue in the application, then it ISN'T here...
